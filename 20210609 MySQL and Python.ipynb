# %%
# conda install pymysql
# anaconda prompt

# %%
import pymysql as m

# %%
con = m.connect(host='localhost', user='root', password='1234', charset='utf8')
cur = con.cursor()

# %%
q = "CREATE DATABASE DB_FROM_PYTHON;"
cur.execute(q)
con.close()
#close 하지 않으면 sql에 리소스 부담
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-4-102babefe5c4> in <module>
#       1 q = "CREATE DATABASE DB_FROM_PYTHON;"
# ----> 2 cur.execute(q)
#       3 con.close()
#       4 #close 하지 않으면 sql에 리소스 부담
#
# C:\Programmierung\Anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# C:\Programmierung\Anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     308         self._last_executed = q
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#     312         return self.rowcount
#
# C:\Programmierung\Anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     546             sql = sql.encode(self.encoding, "surrogateescape")
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#     550
#
# C:\Programmierung\Anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     773         else:
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#     777         if result.server_status is not None:
#
# C:\Programmierung\Anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1154     def read(self):
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#    1158             if first_packet.is_ok_packet():
#
# C:\Programmierung\Anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     723             if self._result is not None and self._result.unbuffered_active is True:
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#     727
#
# C:\Programmierung\Anaconda3\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     219         if DEBUG:
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#     223     def dump(self):
#
# C:\Programmierung\Anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     141     if errorclass is None:
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# ProgrammingError: (1007, "Can't create database 'db_from_python'; database exists")

# %%
con = m.connect(host='localhost', user='root', password='1234',
                db = 'DB_FROM_PYTHON', charset='utf8')
cur = con.cursor()
q = """CREATE TABLE table_from_python(
id INTEGER PRIMARY KEY,
name VARCHAR(100),
eamil VARCHAR(100),
division VARCHAR(100)
)
"""
cur.execute(q)
con.commit()
con.close()

# %%
con = m.connect(host='localhost', user='root', password='1234',
                db = 'DB_FROM_PYTHON', charset='utf8')
cur = con.cursor()
q = """INSERT INTO table_from_python2(id, name, division)
VALUES (1, 'kim', 'dev')
"""
cur.execute(q)
con.commit()
con.close()

# %%
# jump to python 62p
mes1 = "hello, {0}".format("Mr.Kim")
print (mes1)

# %%
#실패
con = m.connect(host='localhost', user='root', password='1234',
                db = 'DB_FROM_PYTHON', charset='utf8')
cur = con.cursor()
q = "INSERT INTO talbe_from_python2(id, name, division) VALUES ({0}, {1}, {2})"
cur.execute(q.format(1, "Kim", "SEE")
cur.execute(q.format(2, "Lee", "SEA")
cur.execute(q.format(3, "Park", "SSI")
cur.execute(q)
con.commit()

# %%
con = m.connect(host='localhost', user='root', password='1234',
                db = 'DB_FROM_PYTHON', charset='utf8')
cur = con.cursor()
q = "INSERT INTO table_from_python2(id, name, division) VALUE (%s, %s, %s)"
cur.execute(q, (1, "Kim", "SEE"))
cur.execute(q, (2, "Lee", "SEA"))
cur.execute(q, (3, "Park", "SSI"))
con.commit()
con.close()

# %%
con = m.connect(host='localhost', user='root', password='1234',
                db = 'DB_FROM_PYTHON', charset='utf8')
cur = con.cursor()
q = 'SELECT * FROM table_from_python;'
cur.execute(q)
res = cur.fetchall()
# 코드는 접수 되었으나 파이썬내에 출력이 불가
for data in res:
    print(data)
# 코드를 줄마다 읽어서 출력
con.commit()
con.close()

# %%
con = m.connect(host='localhost', user='root', password='7751', db ='DB_FROM_PYTHON', charset='utf8')
cur = con.cursor()
q = "INSERT INTO table_from_python2(id, name, division) VALUE(%s, %s, %s)" # 전체가 str 이기때문에 id Value 또한 str로 맞춘다.
cur.execute(q, (1, 'Kim', 'DEV'))
cur.execute(q, (2, 'Lee', 'SAL'))
cur.execute(q, (3, 'Park', 'ADM'))
con.commit()
con.close()

# %%
import pandas as pd
con = m.connect(host='localhost', user='root', password='1234',
                db = 'DB_FROM_PYTHON', charset='utf8')
cur = con.cursor()
q = 'SELECT * FROM table_from_python;'
cur.execute(q)
res = cur.fetchall()
# 코드는 접수 되었으나 파이썬내에 출력이 불가
df1 = pd.DataFrame(res)
con.commit()
con.close()

# %%
import pandas as pd
con = m.connect(host='localhost', user='root', password='1234',
                db = 'DB_FROM_PYTHON', charset='utf8')
cur = con.cursor()
q = 'SELECT * FROM table_from_python;'
cur.execute(q)
res = cur.fetchall()
col = ["id", "name", "email", "division"]
# 코드는 접수 되었으나 파이썬내에 출력이 불가
df1 = pd.DataFrame(res, coulumns = col)
con.close()
df1.to_csv("my_csv2.csv")

# %%
con = m.connect(host='localhost', user='root', password='1234',
                db = 'DB_FROM_PYTHON', charset='utf8')
cur = con.cursor()
q = "UPDATE TABLE_FROM_PYTHON SET email =%s WHERE id =%s;"
cur.execute(q, ("asd1.@a.com", 1))
cur.execute(q, ("asd2.@a.com", 2))
cur.execute(q, ("asd3.@a.com", 3))
con.commit()
con.close()

# %%
con = m.connect(host='localhost', user='root', password='1234', db ='DB_FROM_PYTHON', charset='utf8')
cur = con.cursor()
q = """CREATE TABLE table_from_python3(
id INTEGER PRIMARY KEY,
name VARCHAR(100),
email VARCHAR(100),
division VARCHAR(100)
) 
"""

cur.execute(q)
con.commit()
con.close()

# %%
con = m.connect(host='localhost', user='root', password='1234', db ='DB_FROM_PYTHON', charset='utf8')
cur = con.cursor()
q = "INSERT INTO table_from_python3(id, name, division) VALUE(%s, %s, %s)" # 전체가 str 이기때문에 id Value 또한 str로 맞춘다.
cur.execute(q, (1, 'Kim', 'DEV'))
cur.execute(q, (2, 'Lee', 'SAL'))
cur.execute(q, (3, 'Park', 'ADM'))
con.commit()
con.close()

# %%
con = m.connect(host='localhost', user='root', password='1234', db ='DB_FROM_PYTHON', charset='utf8')
cur = con.cursor()
q = "INSERT INTO table_from_python3(id, name, division) VALUE(%s, %s, %s)" # 전체가 str 이기때문에 id Value 또한 str로 맞춘다.
cur.execute(q, (1, 'Kim', 'DEV'))
cur.execute(q, (2, 'Lee', 'SAL'))
cur.execute(q, (3, 'Park', 'ADM'))
con.commit()
con.close()

# %%
con = m.connect(host='localhost', user='root', password='1234', db ='DB_FROM_PYTHON', charset='utf8')
cur = con.cursor()
q = "SELECT * FROM table_from_python3"
cur.execute(q)                        # 명령은 했으나 불러올 곳이 없음.
res = cur.fetchall()                  # .fetchall을 사용해 명령 데이터를 받아옴
for data in res:                      # 반복문을 통해 출력
    print(data)
con.close()

# %%
import pandas as pd
con = m.connect(host='localhost', user='root', password='1234', db ='DB_FROM_PYTHON', charset='utf8')
cur = con.cursor()
q = "SELECT * FROM table_from_python3"
cur.execute(q)                        # 명령은 했으나 불러올 곳이 없음.
res = cur.fetchall()                  # .fetchall을 사용해 명령 데이터를 받아옴
df1 = pd.DataFrame(res)
con.close()
df1

# %%
col = ['id', 'name', 'email', 'division']
df1 = pd.DataFrame(res, columns =col)
df1

# %%
con = m.connect(host='localhost', user='root', password='1234', db ='DB_FROM_PYTHON', charset='utf8')
cur = con.cursor()
q = "UPDATE table_from_python3 SET email =%s WHERE id =%s;"
cur.execute(q, ("developer_kim@good.com", 1))
cur.execute(q, ("sales_pro_lee@good.com", 2))
cur.execute(q, ("admin_park@good.com", 3))
con.commit()                
con.close()

# %%
import pandas as pd
df_titanic = pd.read_csv("C:/Programmierung/workspace/Python_2021/examples/titanic_full.csv")

# %%
df_titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...                                                 ...     ...   ...    ...
# 1304                                 Spector, Mr. Woolf    male   NaN      0
# 1305                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 1306                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 1307                                Ware, Mr. Frederick    male   NaN      0
# 1308                           Peter, Master. Michael J    male   NaN      1
#
#       Parch              Ticket      Fare Cabin Embarked  \
# 0         0           A/5 21171    7.2500   NaN        S
# 1         0            PC 17599   71.2833   C85        C
# 2         0    STON/O2. 3101282    7.9250   NaN        S
# 3         0              113803   53.1000  C123        S
# 4         0              373450    8.0500   NaN        S
# ...     ...                 ...       ...   ...      ...
# 1304      0           A.5. 3236    8.0500   NaN        S
# 1305      0            PC 17758  108.9000  C105        C
# 1306      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307      0              359309    8.0500   NaN        S
# 1308      1                2668   22.3583   NaN        C
#
#                                 Hometown      Boarded  \
# 0             Bridgerule, Devon, England  Southampton
# 1                 New York, New York, US    Cherbourg
# 2                     Jyv채skyl채, Finland  Southampton
# 3            Scituate, Massachusetts, US  Southampton
# 4     Birmingham, West Midlands, England  Southampton
# ...                                  ...          ...
# 1304                     London, England  Southampton
# 1305                       Madrid, Spain    Cherbourg
# 1306        Skaun, S첩r-Tr첩ndelag, Norway  Southampton
# 1307          Greenwich, London, England  Southampton
# 1308                   Sar'al[81], Syria    Cherbourg
#
#                                   Destination Lifeboat  Body
# 0     Qu'Appelle Valley, Saskatchewan, Canada      NaN   NaN
# 1                      New York, New York, US        4   NaN
# 2                               New York City      14?   NaN
# 3                 Scituate, Massachusetts, US        D   NaN
# 4                               New York City      NaN   NaN
# ...                                       ...      ...   ...
# 1304                            New York City      NaN   NaN
# 1305                   New York, New York, US        8   NaN
# 1306                                       US      NaN  32MB
# 1307                            New York City      NaN   NaN
# 1308                    Detroit, Michigan, US        D   NaN
#
# [1309 rows x 17 columns]

# %%
df_tita_2 = df_titanic
df_c = df_tita_2.corr()
df_c
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.028814 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.408106  0.060832  0.018322
# Age             0.028814 -0.077221 -0.408106  1.000000 -0.243699 -0.150917
# SibSp          -0.055224 -0.035322  0.060832 -0.243699  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.150917  0.373587  1.000000
# Fare            0.031428  0.257307 -0.558629  0.178740  0.160238  0.221539
#
#                  Fare
# PassengerId  0.031428
# Survived     0.257307
# Pclass      -0.558629
# Age          0.178740
# SibSp        0.160238
# Parch        0.221539
# Fare         1.000000

# %%
df_tita_2 = df_titanic[["PassengerId", "Survived", "Pclass", "Sex", "Age", "SipSp", "Parch", "Fare"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-431981b67387> in <module>
# ----> 1 df_tita_2 = df_titanic[["PassengerId", "Survived", "Pclass", "Sex", "Age", "SipSp", "Parch", "Fare"]]
#
# C:\Programmierung\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# C:\Programmierung\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# C:\Programmierung\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314             if raise_missing:
#    1315                 not_found = list(set(key) - set(ax))
# -> 1316                 raise KeyError(f"{not_found} not in index")
#    1317
#    1318             not_found = key[missing_mask]
#
# KeyError: "['SipSp'] not in index"

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %%
sn.heatmap(df_c, annot=True)
plt.show()

# %%
sn.heatmap(df_c)
plt.show()
