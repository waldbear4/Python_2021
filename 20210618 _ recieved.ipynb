# %%
# 77pg
import mglearn
X, y = mglearn.datasets.load_extended_boston()

# %%
X.shape
# Out:
# (506, 104)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
lr = LinearRegression().fit(X_train, y_train)

# %%
from sklearn.linear_model import Ridge
ridge = Ridge().fit(X_train, y_train)
ridge10 = Ridge(alpha=10).fit(X_train, y_train)
ridge01 = Ridge(alpha=0.1).fit(X_train, y_train)

# %%
import matplotlib.pyplot as plt
plt.plot(ridge.coef_, '^', label='alpha=10')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-cbf60f1c3530> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.plot(ridge.coef_, '^', label='alpha=10')
#       3 plt.show()
#
# NameError: name 'ridge' is not defined

# %%
# 계수 : 104개. 입력데이터 104개
ridge.coef_.shape
# Out:
# (104,)

# %%
X_train.shape
# Out:
# (379, 104)

# %%
import matplotlib.pyplot as plt
plt.plot(ridge.coef_, '^', label='alpha=1')
plt.plot(ridge10.coef_, 's', label='alpha=10')
plt.plot(ridge01.coef_, 'v', label='alpha=0.1')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(ridge.coef_, '^', label='alpha=1')
plt.plot(ridge10.coef_, 's', label='alpha=10')
plt.plot(ridge01.coef_, 'v', label='alpha=0.1')
plt.plot(lr.coef_, 'o', label='Linear')
plt.legend()
plt.show()

# %%
mglearn.plots.plot_ridge_n_samples()

# %%
from sklearn.linear_model import Lasso
lasso = Lasso().fit(X_train, y_train)

# %%
lasso.score(X_train, y_train)
# Out:
# 0.29323768991114607

# %%
lasso.score(X_test, y_test)
# Out:
# 0.20937503255272294

# %%
import numpy as np
np.sum(lasso.coef_ != 0)
# Out:
# 4

# %%
lasso001 = Lasso(alpha=0.01, max_iter=50000).fit(X_train, y_train)

# %%
lasso00001 = Lasso(alpha=0.0001, max_iter=50000).fit(X_train, y_train)

# %%
plt.plot(lasso.coef_, 's')
plt.plot(lasso001.coef_, '^')
plt.plot(lasso00001.coef_, 'v')
plt.show()

# %%
plt.plot(lasso.coef_, 's')
plt.plot(lasso001.coef_, '^')
plt.plot(lasso00001.coef_, 'v')

plt.plot(ridge01.coef_, 'o')
plt.show()

# %%
np.sum(lasso001.coef_ != 0)
# Out:
# 33

# %%
np.sum(lasso00001.coef_ != 0)
# Out:
# 96

# %%
# 86pg
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC

# %%
X, y = mglearn.datasets.make_forge()
# Out:
# C:\Users\CPB06GameN\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:86: FutureWarning: Function make_blobs is deprecated; Please import make_blobs directly from scikit-learn
#   warnings.warn(msg, category=FutureWarning)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 3))

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 3))
for model, ax in zip([LinearSVC(max_iter=5000), LogisticRegression()], axes):
    clf = model.fit(X, y)
    mglearn.plots.plot_2d_separator(clf, X, ax=ax)
    mglearn.discrete_scatter(X[:, 0], X[:, 1], y, ax=ax)

# %%
mglearn.plots.plot_linear_svc_regularization()

# %%
# 89pg
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(
cancer.data, cancer.target, stratify=cancer.target, random_state=42)
logreg = LogisticRegression(C=1, max_iter=5000).fit(X_train, y_train)
logreg100 = LogisticRegression(C=100, max_iter=5000).fit(X_train, y_train)
logreg001 = LogisticRegression(C=0.01, max_iter=5000).fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-55d16c828c03> in <module>
#       4 X_train, X_test, y_train, y_test = train_test_split(
#       5 cancer.data, cancer.target, stratify=cancer.target, random_state=42)
# ----> 6 logreg = LogisticRegression(C=1, max_iter=5000).fit(X_train, y_train)
#       7 logreg100 = LogisticRegression(C=100, max_iter=5000).fit(X_train, y_train)
#       8 logreg001 = LogisticRegression(C=0.01, max_iter=5000).fit(X_train, y_train)
#
# NameError: name 'LogisticRegression' is not defined

# %%
logreg001.coef_.shape
# Out:
# (1, 30)

# %%
plt.plot(logreg.coef_.T, '^')
plt.plot(logreg100.coef_.T, 'o')
plt.plot(logreg001.coef_.T, 'v')
plt.xticks(range(cancer.data.shape[1]), cancer.feature_names,rotation=90)
plt.show()

# %%
# !pip install graphviz
# Out:
# Collecting graphviz
#   Downloading graphviz-0.16-py2.py3-none-any.whl (19 kB)
# Installing collected packages: graphviz
# Successfully installed graphviz-0.16

# %%
# https://graphviz.org/download/

# %%
mglearn.plots.plot_animal_tree()

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
mglearn.plots.plot
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-bf63d5797d0b> in <module>
# ----> 1 mglearn.plots.plot
#
# AttributeError: module 'mglearn.plots' has no attribute 'plot'
