# %%
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd

# %%
crime_CSA = pd.read_csv('C:/Programmierung/workspace/Python_2021/examples/Crime/Crime_City_Sex_Age_total.csv')
crime_CSA
# Out:
#     죄종별(1)       죄종별(2)     2012   2012.1  2012.2  2012.3  2012.4  2012.5  \
# 0   죄종별(1)       죄종별(2)        계       남자      남자      남자      남자      남자
# 1   죄종별(1)       죄종별(2)        계        계   20세이하  21-30세  31-40세  41-50세
# 2        계           소계  1723815  1406840  115589  233412  304219  375745
# 3     강력범죄           소계    23789    22819    4116    4904    4803    4756
# 4     강력범죄         살인기수      446      345       8      46      79      93
# 5     강력범죄        살인미수등      610      542      18      76     100     193
# 6     강력범죄           강도     3322     3061     991     801     635     416
# 7     강력범죄      강간·강제추행    18012    17641    2892    3886    3796    3670
# 8     강력범죄           강간        -        -       -       -       -       -
# 9     강력범죄         유사강간        -        -       -       -       -       -
# 10    강력범죄         강제추행        -        -       -       -       -       -
# 11    강력범죄  기타 강간·강제추행등        -        -       -       -       -       -
# ...

# %%
crime_CSA2 = crime_CSA
crime_CSA_C = crime_CSA2.corr()
crime_CSA_C
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
sn.heatmap(crime_CSA_C, annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-909527169b29> in <module>
# ----> 1 sn.heatmap(crime_CSA_C, annot=True)
#       2 plt.show()
#
# C:\Programmierung\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\Programmierung\Anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     533     """
#     534     # Initialize the plotter object
# --> 535     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
# ...

# %%
data = []
index = ["a", "b", "c", "d"]
plt.barh(index, data, color = "b",)
plt.show()

# %%
crime_CSAe = pd.read_csv('C:/Programmierung/workspace/Python_2021/examples/Crime/Crime_test3.csv', header=[0,1,2], index_col = 0)
crime_CSAe
# Out:
#                    2012                                                 \
#                       M
# 연도                  u20      u30       u40       u50      u60      u70
# 강력범죄살인기수            8.0     46.0      79.0      93.0     85.0     24.0
# 강력범죄살인미수등          18.0     76.0     100.0     193.0    109.0     28.0
# 강력범죄강도            991.0    801.0     635.0     416.0    172.0     35.0
# 강력범죄강간·강제추행      2892.0   3886.0    3796.0    3670.0   2354.0    747.0
# 강력범죄강간              NaN      NaN       NaN       NaN      NaN      NaN
# 강력범죄유사강간            NaN      NaN       NaN       NaN      NaN      NaN
# 강력범죄강제추행            NaN      NaN       NaN       NaN      NaN      NaN
# 강력범죄기타강간·강제추행등      NaN      NaN       NaN       NaN      NaN      NaN
# 강력범죄방화            207.0     95.0     193.0     384.0    286.0     46.0
# 절도범죄            36778.0  13508.0   10245.0   10752.0   8378.0   3009.0
# 폭력범죄폭행           8282.0  22168.0   31170.0   41965.0  30015.0   7589.0
# ...

# %%
crime_CSAe.transpose()
# Out:
#                 강력범죄살인기수  강력범죄살인미수등  강력범죄강도  강력범죄강간·강제추행  강력범죄강간  강력범죄유사강간  \
#        연도
# 2012 M u20           8.0       18.0   991.0       2892.0     NaN       NaN
#        u30          46.0       76.0   801.0       3886.0     NaN       NaN
#        u40          79.0      100.0   635.0       3796.0     NaN       NaN
#        u50          93.0      193.0   416.0       3670.0     NaN       NaN
#        u60          85.0      109.0   172.0       2354.0     NaN       NaN
# ...                  ...        ...     ...          ...     ...       ...
# 2019 F u50          15.0       12.0    19.0        144.0    15.0       3.0
#        u60          17.0       16.0    15.0        133.0    17.0       3.0
#        u70           6.0        8.0     4.0         67.0    13.0       NaN
#        o70           4.0        2.0     6.0         10.0     NaN       NaN
#        unknown       1.0        NaN     1.0          6.0     1.0       1.0
#
# ...

# %%
gagu_str = pd.read_csv('C:/Programmierung/workspace/Python_2021/examples/Crime/gagu_structure_utf8.csv')
gagu_str
# Out:
#     행정구역별(시군구)  가구주의 성별  가구주의 연령별      2019   2019.1    2019.2  \
# 0   행정구역별(시군구)  가구주의 성별  가구주의 연령별      일반가구  1세대가구-계  1세대가구-부부
# 1           전국        계        합계  20343188  3752000   3389074
# 2           전국        계     15세미만        96       11         X
# 3           전국        계    15~19세     63075     2842         7
# 4           전국        계    20~24세    519327    32857      2617
# 5           전국        계    25~29세   1008218   117448     53511
# 6           전국        계    30~34세   1277367   210646    163145
# 7           전국        계    35~39세   1846492   180942    149214
# 8           전국        계    40~44세   1911873   124181     99300
# 9           전국        계    45~49세   2346638   176343    149147
# 10          전국        계    50~54세   2380388   276204    249131
# 11          전국        계    55~59세   2419951   440618    409787
# 12          전국        계    60~64세   2111640   620241    587312
# 13          전국        계    65~69세   1417761   537225    518902
# ...

# %%
crime_repeat = pd.read_csv('C:/Programmierung/workspace/Python_2021/examples/Crime/crime_repeat_utf8.csv')
crime_repeat
# Out:
#         범죄별   전과별   2012 년   2013 년   2014 년   2015 년   2016 년     2017 년  \
# 0        합계    합계  2117737  2147250  1879548  1948966  2020196  1861796.0
# 1        합계  전과없음   451710   426343   411192   416301   437154   398684.0
# 2        합계    전과   883374   896404   852244   859477   897996   811653.0
# 3        합계    1범   209365   205878   195701   195253   202982   182989.0
# 4        합계    2범   141796   143901   136751   135757   140792   127597.0
# ...     ...   ...      ...      ...      ...      ...      ...        ...
# 3115  기타특별법    6범     2667     2871     1130     1144     1326     1473.0
# 3116  기타특별법    7범     2152     2304      820      819      988     1133.0
# 3117  기타특별법    8범     1593     1673      669      727      735      858.0
# 3118  기타특별법  9범이상     7461     8688     3231     3587     4047     4540.0
# 3119  기타특별법    미상    28110    34188     7364     8448     9006    12929.0
#
#        2018 년   2019 년
# 0     1749459  1754808
# 1      362702   366305
# ...

# %%
crime_repeat.head(20)
# Out:
#     범죄별   전과별   2012 년   2013 년   2014 년   2015 년   2016 년     2017 년  \
# 0    합계    합계  2117737  2147250  1879548  1948966  2020196  1861796.0
# 1    합계  전과없음   451710   426343   411192   416301   437154   398684.0
# 2    합계    전과   883374   896404   852244   859477   897996   811653.0
# 3    합계    1범   209365   205878   195701   195253   202982   182989.0
# 4    합계    2범   141796   143901   136751   135757   140792   127597.0
# 5    합계    3범   106471   105536    99471    98909   103323    93621.0
# 6    합계    4범    78611    78783    74802    75009    78001    70358.0
# 7    합계    5범    60743    62305    58337    59094    62230    55108.0
# 8    합계    6범    47348    48093    45854    46225    48508    43763.0
# 9    합계    7범    37320    38169    35213    36048    37991    33553.0
# 10   합계    8범    30326    30866    28799    29271    30401    27214.0
# 11   합계  9범이상   171394   182873   177316   183911   193768   177450.0
# ...
